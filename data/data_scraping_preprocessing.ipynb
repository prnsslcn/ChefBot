# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.2
# debugpy                 1.8.13
# decorator               5.2.1
# executing               2.2.0
# ipykernel               6.29.5
# ipython                 9.0.2
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# packaging               24.2
# parso                   0.8.4
# pip                     24.3.1
# platformdirs            4.3.6
# prompt_toolkit          3.0.50
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.1
# python-dateutil         2.9.0.post0
# pywin32                 309
# pyzmq                   26.2.1
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.4.2
# traitlets               5.14.3
# wcwidth                 0.2.13

# %%
# pandas, numpy 라이브러리 설치
# !pip install pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# requests, beautifulSoup 라이브러리 설치
# !pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, typing-extensions, soupsieve, idna, charset-normalizer, certifi, requests, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.3 certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 soupsieve-2.6 typing-extensions-4.12.2 urllib3-2.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 메뉴명 추출
import os
import pandas as pd
    
# 메뉴 데이터가 있는 폴더 경로 설정
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "./menu"))  # 상대경로 정리
menu_folder = os.path.join(data_path)

# CSV 파일 목록 가져오기
csv_files = [f for f in os.listdir(menu_folder) if f.endswith('.csv')]

# 여러 개의 CSV 파일을 하나의 DataFrame으로 합치기
menu_data_list = []
for file in csv_files:
    file_path = os.path.join(menu_folder, file)
    df = pd.read_csv(file_path, encoding='cp949') # 한글 인코딩
    df['source_file'] = file 
    menu_data_list.append(df)

# 모든 데이터를 하나의 DataFrame으로 합치기
combined_menu_data = pd.concat(menu_data_list, ignore_index=True)

# 데이터의 MENU_NM 컬람 값으로 리스트 만들기
menu_list = combined_menu_data['MENU_NM'].tolist()

# 최신 메뉴.txt 데이터 리스트에 삽입
with open(f'{data_path}/popular_menu_these_days.txt', 'r', encoding='utf-8') as f:
    temp_list = ([line.strip() for line in f.readlines()])  
    menu_list.extend(temp_list)

# 중복 제거
unique_menu_list = list(set(menu_list))

# 중복 제거한 리스트 개수 출력
print(f'중복 제거한 메뉴 개수: {len(unique_menu_list)}')

# 중복 제거한 리스트 일부 출력
unique_menu_list[:10]
# Out:
# 중복 제거한 메뉴 개수: 366
# ['오리로스·주물럭·훈제',
#  '연어 샌드위치',
#  '토마토 수프',
#  '흑당 버블티',
#  '까르보나라 스파게티',
#  '버섯 오일 파스타',
#  '반반치킨',
#  '그라탕',
#  '밤티라미수',
#  '기타시즈닝치킨']

# %%
# 성능 개선을 위해 230개 메뉴 추가
import os
import pandas as pd

# unique_menu_list 리스트 초기화
unique_menu_list = []
menu_list = []
# 메뉴 데이터가 있는 폴더 경로 설정
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "./menu"))  # 상대경로 정리
menu_folder = os.path.join(data_path)
print(data_path)
# 한국 메뉴.txt 데이터 리스트에 삽입
with open(f'{data_path}/korea_foods.txt', 'r', encoding='utf-8') as f:
    temp_list = ([line.strip() for line in f.readlines()])  
    menu_list.extend(temp_list)

# 중복 제거
unique_menu_list = list(set(menu_list))

# 중복 제거한 리스트 개수 출력
print(f'중복 제거한 메뉴 개수: {len(unique_menu_list)}')

# 중복 제거한 리스트 일부 출력
unique_menu_list[:100]
# Out:
# c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\menu
# 중복 제거한 메뉴 개수: 228
# ['닭볶음탕',
#  '김치알밥',
#  '매실차',
#  '나박김치',
#  '귤피차',
#  '갈치조림',
#  '낙지덮밥',
#  '게국지',
#  '깻잎순볶음',
#  '녹차',
#  '프라이드치킨',
#  '부추전',
#  '동치미',
#  '오리고기 백숙',
#  '표고버섯전',
#  '막창구이',
#  '전복전',
#  '식혜',
#  '참치김치볶음밥',
#  '낙지해물죽',
#  '곱창볶음',
#  '헛개차',
#  '닭강정',
#  '조개구이',
#  '닭갈비',
#  '마늘종 장아찌',
#  '도토리묵 무침',
#  '삼계탕',
#  '시래기국',
#  '치킨무침',
#  '닭발',
#  '조기찌개',
#  '북엇국',
#  '육전',
#  '양념게장',
#  '두부김치',
#  '감자전',
#  '호박잎쌈',
#  '두부튀김',
#  '치킨까스',
#  '오징어볶음밥',
#  '파김치',
#  '수정과',
#  '파래무침',
#  '삼색나물',
#  '새알심 떡국',
#  '버섯솥밥',
#  '김치찌개',
#  '제육볶음',
#  '홍합짬뽕칼국수',
#  '해물탕',
#  '연근조림',
#  '팥칼국수',
#  '고추된장박이',
#  '육개장',
#  '장어구이',
#  '우거지해장국',
#  '석박지',
#  '조기구이',
#  '오징어덮밥',
#  '매운오뎅탕',
#  '떡볶이',
#  '닭칼국수',
#  '간장게장',
#  '갈비찜',
#  '매운어묵볶음',
#  '뚝배기된장찌개',
#  '오리주물럭',
#  '깻잎전',
#  '불고기덮밥',
#  '소불고기',
#  '대구찜',
#  '닭고기장조림',
#  '해물파전',
#  '묵은지찜닭',
#  '설렁탕',
#  '모과차',
#  '새우장',
#  '녹두죽',
#  '짜장떡볶이',
#  '더덕구이',
#  '삼겹살 김치말이',
#  '매실장아찌',
#  '깻잎김치',
#  '단호박죽',
#  '두부조림',
#  '소불고기 샐러드',
#  '연근튀김',
#  '오징어순대',
#  '육회',
#  '아귀찜',
#  '깻잎 장아찌',
#  '홍합전',
#  '갈비덮밥',
#  '율무차',
#  '삼겹살구이',
#  '대추차',
#  '전주비빔밥',
#  '오미자차',
#  '들깨칼국수']

# %%
import requests, json, os, time, random
from bs4 import BeautifulSoup

# 현재 작업 디렉토리 확인 및 상대 경로 정리
BASE_DIR = os.getcwd()
data_path = os.path.normpath(os.path.join(BASE_DIR, "./recipes"))
os.makedirs(data_path, exist_ok=True)

print(f"데이터 저장 경로: {data_path}")

# 메뉴명을 입력하면 음식 정보를 출력하는 함수 (만개의 레시피 웹 스크래핑)
# 다수 요청시 계속 원격 중단되어 재시도 로직 추가
def food_info(name):
    recipe_list = []
    url = f"https://www.10000recipe.com/recipe/list.html?q={name}"

    # HTTP 요청 실패 시 재시도 (최대 3회)
    for attempt in range(3):
        try:
            response = requests.get(url, timeout=10)  
            if response.status_code == 200:
                break
            else:
                print(f"HTTP 응답 에러 ({response.status_code}), 재시도 {attempt+1}/3")
        except requests.RequestException as e:
            print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
        time.sleep(random.uniform(3, 6)) 

    if response.status_code != 200:
        print(f"요청 실패: {url}")
        return None

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 번째 검색 결과에서 레시피 링크 가져오기
    food_list = soup.find_all(attrs={'class': 'common_sp_link'})
    if not food_list:
        print(f"레시피 검색 결과 없음: {name}")
        return None

    # 레시피는 최대 3개 저장
    for food in food_list[:5]:
        food_id = food['href'].split('/')[-1]
        new_url = f'https://www.10000recipe.com/recipe/{food_id}'

        # HTTP 요청 실패 시 재시도 (최대 3회)
        for attempt in range(3):
            try:
                new_response = requests.get(new_url, timeout=10)
                if new_response.status_code == 200:
                    break
                else:
                    print(f"레시피 페이지 요청 실패 ({new_response.status_code}), 재시도 {attempt+1}/3")
            except requests.RequestException as e:
                print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
            time.sleep(random.uniform(3, 6))

        if new_response.status_code != 200:
            print(f"레시피 페이지 요청 실패: {new_url}")
            continue

        html = new_response.text
        soup = BeautifulSoup(html, 'html.parser')

        # JSON 데이터 추출
        food_info = soup.find(attrs={'type': 'application/ld+json'})

        # JSON 데이터가 없으면 건너뛰기
        if food_info is None:
            print(f"JSON 데이터 없음: {new_url}")
            continue

        try:
            result = json.loads(food_info.text)  # 🔹 JSON 파싱 시도
        except json.JSONDecodeError:
            print(f"JSON 파싱 실패 (형식 오류): {new_url}")
            continue

        # 'recipeIngredient'와 'recipeInstructions'가 있는지 확인
        if 'recipeIngredient' in result and 'recipeInstructions' in result:
            ingredient = ', '.join(result['recipeIngredient'])
            recipe = [step['text'] for step in result['recipeInstructions']]
            recipe = [f'{i+1}. {step}' for i, step in enumerate(recipe)]

            recipe_list.append({
                'name': name,
                'ingredients': ingredient,
                'recipe': recipe
            })

    # 3개 모두 정보가 없으면 "정보 없음" 처리
    if not recipe_list:
        recipe_list.append({
            'name': name,
            'ingredients': "정보 없음",
            'recipe': ["정보 없음"]
        })

    return recipe_list

# json 데이터를 파일로 저장하는 함수
def save_json(data, file_name):
    try:
        with open(file_name, 'w', encoding='utf-8') as file:
            json.dump(data, file, ensure_ascii=False, indent='\t')
            file.flush()
    except Exception as e:
        print(f"파일 저장 오류: {e}")

# 메뉴명 리스트로 레시피 생성 (딜레이 추가)
for i, menu in enumerate(unique_menu_list):
    print(f"\n({i+1}/{len(unique_menu_list)}) {menu} 레시피 검색 중...")

    res = food_info(menu)
    if res:
        safe_file_name = menu.replace(" ", "_").replace("/", "_").replace("\\", "_")
        file_path = os.path.join(data_path, f"{safe_file_name}_recipe.json")
        save_json(res, file_path)
        print(f"저장 완료: {file_path}")
    else:
        print(f'{menu}: 레시피를 찾을 수 없습니다.')

    # 요청 속도를 줄이기 위해 랜덤 대기 (3~6초)
    time.sleep(random.uniform(3, 6))
# Out:
# 데이터 저장 경로: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes
#
# (1/228) 닭볶음탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭볶음탕_recipe.json
#
# (2/228) 김치알밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\김치알밥_recipe.json
#
# (3/228) 매실차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\매실차_recipe.json
#
# (4/228) 나박김치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\나박김치_recipe.json
#
# (5/228) 귤피차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\귤피차_recipe.json
#
# (6/228) 갈치조림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈치조림_recipe.json
#
# (7/228) 낙지덮밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\낙지덮밥_recipe.json
#
# (8/228) 게국지 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\게국지_recipe.json
#
# (9/228) 깻잎순볶음 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\깻잎순볶음_recipe.json
#
# (10/228) 녹차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\녹차_recipe.json
#
# (11/228) 프라이드치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\프라이드치킨_recipe.json
#
# (12/228) 부추전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\부추전_recipe.json
#
# (13/228) 동치미 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\동치미_recipe.json
#
# (14/228) 오리고기 백숙 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오리고기_백숙_recipe.json
#
# (15/228) 표고버섯전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\표고버섯전_recipe.json
#
# (16/228) 막창구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\막창구이_recipe.json
#
# (17/228) 전복전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\전복전_recipe.json
#
# (18/228) 식혜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\식혜_recipe.json
#
# (19/228) 참치김치볶음밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치김치볶음밥_recipe.json
#
# (20/228) 낙지해물죽 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\낙지해물죽_recipe.json
#
# (21/228) 곱창볶음 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\곱창볶음_recipe.json
#
# (22/228) 헛개차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\헛개차_recipe.json
#
# (23/228) 닭강정 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭강정_recipe.json
#
# (24/228) 조개구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\조개구이_recipe.json
#
# (25/228) 닭갈비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭갈비_recipe.json
#
# (26/228) 마늘종 장아찌 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마늘종_장아찌_recipe.json
#
# (27/228) 도토리묵 무침 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\도토리묵_무침_recipe.json
#
# (28/228) 삼계탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\삼계탕_recipe.json
#
# (29/228) 시래기국 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\시래기국_recipe.json
#
# (30/228) 치킨무침 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치킨무침_recipe.json
#
# (31/228) 닭발 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭발_recipe.json
#
# (32/228) 조기찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\조기찌개_recipe.json
#
# (33/228) 북엇국 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\북엇국_recipe.json
#
# (34/228) 육전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\육전_recipe.json
#
# (35/228) 양념게장 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\양념게장_recipe.json
#
# (36/228) 두부김치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\두부김치_recipe.json
#
# (37/228) 감자전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자전_recipe.json
#
# (38/228) 호박잎쌈 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\호박잎쌈_recipe.json
#
# (39/228) 두부튀김 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\두부튀김_recipe.json
#
# (40/228) 치킨까스 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치킨까스_recipe.json
#
# (41/228) 오징어볶음밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오징어볶음밥_recipe.json
#
# (42/228) 파김치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\파김치_recipe.json
#
# (43/228) 수정과 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\수정과_recipe.json
#
# (44/228) 파래무침 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\파래무침_recipe.json
#
# (45/228) 삼색나물 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\삼색나물_recipe.json
#
# (46/228) 새알심 떡국 레시피 검색 중...
