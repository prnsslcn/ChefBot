# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.2
# debugpy                 1.8.13
# decorator               5.2.1
# executing               2.2.0
# ipykernel               6.29.5
# ipython                 9.0.2
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# packaging               24.2
# parso                   0.8.4
# pip                     24.3.1
# platformdirs            4.3.6
# prompt_toolkit          3.0.50
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.1
# python-dateutil         2.9.0.post0
# pywin32                 309
# pyzmq                   26.2.1
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.4.2
# traitlets               5.14.3
# wcwidth                 0.2.13

# %%
# pandas, numpy 라이브러리 설치
# !pip install pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# requests, beautifulSoup 라이브러리 설치
# !pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, typing-extensions, soupsieve, idna, charset-normalizer, certifi, requests, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.3 certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 soupsieve-2.6 typing-extensions-4.12.2 urllib3-2.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import os
# Out:
# c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\menu

# %%
# 메뉴명 추출
import os
import pandas as pd
    
# 메뉴 데이터가 있는 폴더 경로 설정
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "./menu"))  # 상대경로 정리
menu_folder = os.path.join(data_path)

# CSV 파일 목록 가져오기
csv_files = [f for f in os.listdir(menu_folder) if f.endswith('.csv')]

# 여러 개의 CSV 파일을 하나의 DataFrame으로 합치기
menu_data_list = []
for file in csv_files:
    file_path = os.path.join(menu_folder, file)
    df = pd.read_csv(file_path, encoding='cp949') # 한글 인코딩
    df['source_file'] = file 
    menu_data_list.append(df)

# 모든 데이터를 하나의 DataFrame으로 합치기
combined_menu_data = pd.concat(menu_data_list, ignore_index=True)

# 데이터의 MENU_NM 컬람 값으로 리스트 만들기
menu_list = combined_menu_data['MENU_NM'].tolist()

# 최신 메뉴.txt 데이터 리스트에 삽입
with open(f'{data_path}/popular_menu_these_days.txt', 'r', encoding='utf-8') as f:
    temp_list = ([line.strip() for line in f.readlines()])  
    menu_list.extend(temp_list)

# 중복 제거
unique_menu_list = list(set(menu_list))

# 중복 제거한 리스트 개수 출력
print(f'중복 제거한 메뉴 개수: {len(unique_menu_list)}')

# 중복 제거한 리스트 일부 출력
unique_menu_list[:10]
# Out:
# 중복 제거한 메뉴 개수: 366
# ['백반',
#  '아이스 아메리카노',
#  '아메리카노',
#  '곰장어 요리',
#  '초당옥수수 아이스크림',
#  '소떡소떡',
#  '바질 크로아상',
#  '페이스트리 크로넛',
#  '두부요리',
#  '민트초코 아이스크림']

# %%
import requests, json, os, time, random
from bs4 import BeautifulSoup

# 현재 작업 디렉토리 확인 및 상대 경로 정리
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "./recipes"))  # 상대경로 정리
os.makedirs(data_path, exist_ok=True)  # 폴더가 없으면 생성

print(f"데이터 저장 경로: {data_path}")

# 메뉴명을 입력하면 음식 정보를 출력하는 함수 (만개의 레시피 웹 스크래핑)
def food_info(name):
    recipe_list = []
    url = f"https://www.10000recipe.com/recipe/list.html?q={name}"

    # HTTP 요청 실패 시 재시도 (최대 3회)
    # 다수 요청시 계속 원격 중단되어 재시도 로직 추가
    for attempt in range(3):
        try:
            response = requests.get(url, timeout=10)  
            if response.status_code == 200:
                break
            else:
                print(f"HTTP 응답 에러 ({response.status_code}), 재시도 {attempt+1}/3")
        except requests.RequestException as e:
            print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
        time.sleep(random.uniform(3, 6)) 

    if response.status_code != 200:
        print(f"요청 실패: {url}")
        return None

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 번째 검색 결과에서 레시피 링크 가져오기
    food_list = soup.find_all(attrs={'class': 'common_sp_link'})
    if not food_list:
        print(f"레시피 검색 결과 없음: {name}")
        return None
    
    # 레시피는 최대 3개 저장
    for food in food_list[:3]:
        food_id = food['href'].split('/')[-1]
        new_url = f'https://www.10000recipe.com/recipe/{food_id}'

        # HTTP 요청 실패 시 재시도 (최대 3회)
        for attempt in range(3):
            try:
                new_response = requests.get(new_url, timeout=10)
                if new_response.status_code == 200:
                    break
                else:
                    print(f"레시피 페이지 요청 실패 ({new_response.status_code}), 재시도 {attempt+1}/3")
            except requests.RequestException as e:
                print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
            time.sleep(random.uniform(3, 6))  # 재시도 간격 랜덤 (3~6초)

        if new_response.status_code != 200:
            print(f"레시피 페이지 요청 실패: {new_url}")
            continue

        html = new_response.text
        soup = BeautifulSoup(html, 'html.parser')

        # JSON 데이터 추출
        food_info = soup.find(attrs={'type': 'application/ld+json'})
        if food_info is None:
            print(f"JSON 데이터 없음: {new_url}")
            continue

        result = json.loads(food_info.text)

        # 'recipeIngredient'와 'recipeInstructions'가 있는지 확인
        if 'recipeIngredient' in result and 'recipeInstructions' in result:
            ingredient = ', '.join(result['recipeIngredient'])
            recipe = [step['text'] for step in result['recipeInstructions']]
            recipe = [f'{i+1}. {step}' for i, step in enumerate(recipe)]

            recipe_list.append({
                'name': name,
                'ingredients': ingredient,
                'recipe': recipe
            })

    # 3개 모두 정보가 없으면 "정보 없음" 처리
    if not recipe_list:
        recipe_list.append({
            'name': name,
            'ingredients': "정보 없음",
            'recipe': ["정보 없음"]
        })

    return recipe_list

# json 데이터를 파일로 저장하는 함수
def save_json(data, file_name):
    try:
        with open(file_name, 'w', encoding='utf-8') as file:
            json.dump(data, file, ensure_ascii=False, indent='\t')
            file.flush()  # 데이터 손실 방지
    except Exception as e:
        print(f"파일 저장 오류: {e}")

# 메뉴명 리스트로 레시피 생성 (딜레이 추가)
for i, menu in enumerate(unique_menu_list):
    print(f"\n({i+1}/{len(unique_menu_list)}) {menu} 레시피 검색 중...")

    res = food_info(menu)
    if res:
        safe_file_name = menu.replace(" ", "_").replace("/", "_").replace("\\", "_")
        file_path = os.path.join(data_path, f"{safe_file_name}_recipe.json")
        save_json(res, file_path)
        print(f"저장 완료: {file_path}")
    else:
        print(f'{menu}: 레시피를 찾을 수 없습니다.')

    # 요청 속도를 줄이기 위해 랜덤 대기 (3~6초)
    time.sleep(random.uniform(3, 6))
# Out:
# 데이터 저장 경로: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes
#
# (1/366) 백반 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\백반_recipe.json
#
# (2/366) 아이스 아메리카노 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아이스_아메리카노_recipe.json
#
# (3/366) 아메리카노 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아메리카노_recipe.json
#
# (4/366) 곰장어 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\곰장어_요리_recipe.json
#
# (5/366) 초당옥수수 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초당옥수수_아이스크림_recipe.json
#
# (6/366) 소떡소떡 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소떡소떡_recipe.json
#
# (7/366) 바질 크로아상 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_크로아상_recipe.json
#
# (8/366) 페이스트리 크로넛 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\페이스트리_크로넛_recipe.json
#
# (9/366) 두부요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\두부요리_recipe.json
#
# (10/366) 민트초코 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\민트초코_아이스크림_recipe.json
#
# (11/366) 공기밥·돌솥밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\공기밥·돌솥밥_recipe.json
#
# (12/366) 해산물 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\해산물_파스타_recipe.json
#
# (13/366) 에그타르트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\에그타르트_recipe.json
#
# (14/366) 샤브샤브 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\샤브샤브_recipe.json
#
# (15/366) 라떼류커피 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\라떼류커피_recipe.json
#
# (16/366) 오리탕·오리백숙 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오리탕·오리백숙_recipe.json
#
# (17/366) 훈제 연어 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\훈제_연어_샐러드_recipe.json
#
# (18/366) 마카롱·와플·파이·타르트·카페디저트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마카롱·와플·파이·타르트·카페디저트_recipe.json
#
# (19/366) 볶음밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\볶음밥_recipe.json
#
# (20/366) 굴요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\굴요리_recipe.json
#
# (21/366) 베이글·식사용빵 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\베이글·식사용빵_recipe.json
#
# (22/366) 똠얌꿍 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\똠얌꿍_recipe.json
#
# (23/366) 하와이안 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\하와이안_피자_recipe.json
#
# (24/366) 트러플 치즈버거 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_치즈버거_recipe.json
#
# (25/366) 소시지 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소시지_recipe.json
#
# (26/366) 버섯 오일 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\버섯_오일_파스타_recipe.json
#
# (27/366) 민물고기 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\민물고기_요리_recipe.json
#
# (28/366) 바질 오믈렛 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_오믈렛_recipe.json
#
# (29/366) 순대 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\순대_recipe.json
#
# (30/366) 국·탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\국·탕_recipe.json
#
# (31/366) 레몬 마들렌 레시피 검색 중...
# JSON 데이터 없음: https://www.10000recipe.com/recipe/6965943
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\레몬_마들렌_recipe.json
#
# (32/366) 아보카도 토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아보카도_토스트_recipe.json
#
# (33/366) 수제버거 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\수제버거_recipe.json
#
# (34/366) 인절미 토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\인절미_토스트_recipe.json
#
# (35/366) 토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\토스트_recipe.json
#
# (36/366) 명란 크림 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\명란_크림_파스타_recipe.json
#
# (37/366) 새우구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\새우구이_recipe.json
#
# (38/366) 흑염소 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑염소_recipe.json
#
# (39/366) 감자 갈릭버터구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자_갈릭버터구이_recipe.json
#
# (40/366) 흑당 버블티 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑당_버블티_recipe.json
#
# (41/366) 불고기 크레페 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불고기_크레페_recipe.json
#
# (42/366) 페스토 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\페스토_파스타_recipe.json
#
# (43/366) 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\파스타_recipe.json
#
# (44/366) 흑임자 와플 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑임자_와플_recipe.json
#
# (45/366) 전복죽 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\전복죽_recipe.json
#
# (46/366) 정식 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\정식_recipe.json
#
# (47/366) 돼지고기 구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돼지고기_구이_recipe.json
#
# (48/366) 연어 포케 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\연어_포케_recipe.json
#
# (49/366) 타다끼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타다끼_recipe.json
#
# (50/366) 트러플 감자튀김 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_감자튀김_recipe.json
#
# (51/366) 생선찜·해물찜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\생선찜·해물찜_recipe.json
#
# (52/366) 밀푀유 나베 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\밀푀유_나베_recipe.json
#
# (53/366) 매운 닭볶음탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\매운_닭볶음탕_recipe.json
#
# (54/366) 바질 페스토 닭가슴살 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_페스토_닭가슴살_recipe.json
#
# (55/366) 쿠키 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쿠키_recipe.json
#
# (56/366) 까르보나라 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\까르보나라_recipe.json
#
# (57/366) 프렌치 카라멜 푸딩 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\프렌치_카라멜_푸딩_recipe.json
#
# (58/366) 뷔페·식권 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\뷔페·식권_recipe.json
#
# (59/366) 해장국 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\해장국_recipe.json
#
# (60/366) 크림치즈 베이글 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크림치즈_베이글_recipe.json
#
# (61/366) 김치 수제비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\김치_수제비_recipe.json
#
# (62/366) 랍스터 롤 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\랍스터_롤_recipe.json
#
# (63/366) 감자 뇨끼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자_뇨끼_recipe.json
#
# (64/366) 참치 김밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치_김밥_recipe.json
#
# (65/366) 민트초코 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\민트초코_케이크_recipe.json
#
# (66/366) 치즈볼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치즈볼_recipe.json
#
# (67/366) 주스·에이드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\주스·에이드_recipe.json
#
# (68/366) 튀김 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\튀김_recipe.json
#
# (69/366) 불닭볶음면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불닭볶음면_recipe.json
#
# (70/366) 버섯요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\버섯요리_recipe.json
#
# (71/366) 민물장어 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\민물장어_요리_recipe.json
#
# (72/366) 짜장면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\짜장면_recipe.json
#
# (73/366) 프렌치 오믈렛 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\프렌치_오믈렛_recipe.json
#
# (74/366) 사시미 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\사시미_recipe.json
#
# (75/366) 단팥 크루아상 레시피 검색 중...
# JSON 데이터 없음: https://www.10000recipe.com/recipe/6846105
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\단팥_크루아상_recipe.json
#
# (76/366) 덮밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\덮밥_recipe.json
#
# (77/366) 대게찜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\대게찜_recipe.json
#
# (78/366) 함박스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\함박스테이크_recipe.json
#
# (79/366) 감자탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자탕_recipe.json
#
# (80/366) 김치 퀘사디아 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\김치_퀘사디아_recipe.json
#
# (81/366) 감자튀김·사이드메뉴 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자튀김·사이드메뉴_recipe.json
#
# (82/366) 곱창전골 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\곱창전골_recipe.json
#
# (83/366) 허니 마카다미아 브레드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\허니_마카다미아_브레드_recipe.json
#
# (84/366) 고추장찌개·돼지찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고추장찌개·돼지찌개_recipe.json
#
# (85/366) 견과류 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\견과류_recipe.json
#
# (86/366) 트러플 버거 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_버거_recipe.json
#
# (87/366) 생레몬 하이볼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\생레몬_하이볼_recipe.json
#
# (88/366) 제육볶음·두루치기·불고기 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\제육볶음·두루치기·불고기_recipe.json
#
# (89/366) 참치회 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치회_recipe.json
#
# (90/366) 흑임자 크림치즈 샌드위치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑임자_크림치즈_샌드위치_recipe.json
#
# (91/366) 매운 짬뽕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\매운_짬뽕_recipe.json
#
# (92/366) 오징어·먹태·노가리류 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오징어·먹태·노가리류_recipe.json
#
# (93/366) 대구탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\대구탕_recipe.json
#
# (94/366) 고르곤졸라 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고르곤졸라_피자_recipe.json
#
# (95/366) 시저 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\시저_샐러드_recipe.json
#
# (96/366) 조개구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\조개구이_recipe.json
#
# (97/366) 갈비탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈비탕_recipe.json
#
# (98/366) 감바스 알 아히요 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감바스_알_아히요_recipe.json
#
# (99/366) 기타시즈닝치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\기타시즈닝치킨_recipe.json
#
# (100/366) 마라샹궈 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마라샹궈_recipe.json
#
# (101/366) 한우 육회 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\한우_육회_recipe.json
#
# (102/366) 까르보나라 스파게티 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\까르보나라_스파게티_recipe.json
#
# (103/366) 계란찜·계란말이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\계란찜·계란말이_recipe.json
#
# (104/366) 크래미 유부초밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크래미_유부초밥_recipe.json
#
# (105/366) 크림소스 떡볶이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크림소스_떡볶이_recipe.json
#
# (106/366) 벌집 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\벌집_아이스크림_recipe.json
#
# (107/366) 타이 밀크티 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타이_밀크티_recipe.json
#
# (108/366) 전통차·허브차·과일차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\전통차·허브차·과일차_recipe.json
#
# (109/366) 닭갈비 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭갈비_피자_recipe.json
#
# (110/366) 옻닭 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\옻닭_recipe.json
#
# (111/366) 삼계탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\삼계탕_recipe.json
#
# (112/366) 마카다미아 쿠키 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마카다미아_쿠키_recipe.json
#
# (113/366) 탕수육·꿔바로우 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\탕수육·꿔바로우_recipe.json
#
# (114/366) 갈릭쉬림프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈릭쉬림프_recipe.json
#
# (115/366) 김치찌개·참치찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\김치찌개·참치찌개_recipe.json
#
# (116/366) 흑당 카스텔라 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑당_카스텔라_recipe.json
#
# (117/366) 초코칩 쿠키 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초코칩_쿠키_recipe.json
#
# (118/366) 카라멜 마키아토 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\카라멜_마키아토_recipe.json
#
# (119/366) 소보로·슈크림·브라우니·달콤한빵·과자류 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소보로·슈크림·브라우니·달콤한빵·과자류_recipe.json
#
# (120/366) 망고빙수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\망고빙수_recipe.json
#
# (121/366) 유자 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\유자_샐러드_recipe.json
#
# (122/366) 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아이스크림_recipe.json
#
# (123/366) 고르곤졸라 크림 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고르곤졸라_크림_파스타_recipe.json
#
# (124/366) 크랩 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크랩_케이크_recipe.json
#
# (125/366) 토마토 카프레제 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\토마토_카프레제_recipe.json
#
# (126/366) 은행·꼬치구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\은행·꼬치구이_recipe.json
#
# (127/366) 오레오 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오레오_아이스크림_recipe.json
#
# (128/366) 오리로스·주물럭·훈제 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오리로스·주물럭·훈제_recipe.json
#
# (129/366) 더블 초코 마카롱 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\더블_초코_마카롱_recipe.json
#
# (130/366) 와플 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\와플_recipe.json
#
# (131/366) 토마호크 스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\토마호크_스테이크_recipe.json
#
# (132/366) 훈제 오리 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\훈제_오리_샐러드_recipe.json
#
# (133/366) 참치 타다키 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치_타다키_recipe.json
#
# (134/366) 바질 크림 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_크림_파스타_recipe.json
#
# (135/366) 말차 크레이프 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\말차_크레이프_케이크_recipe.json
#
# (136/366) 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\케이크_recipe.json
#
# (137/366) 복숭아 홍차 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\복숭아_홍차_recipe.json
#
# (138/366) 퐁당 쇼콜라 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\퐁당_쇼콜라_recipe.json
#
# (139/366) 문어 카르파초 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\문어_카르파초_recipe.json
#
# (140/366) 카레 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\카레_recipe.json
#
# (141/366) 설렁탕·곰탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\설렁탕·곰탕_recipe.json
#
# (142/366) 닭갈비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭갈비_recipe.json
#
# (143/366) 크로크마담 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크로크마담_recipe.json
#
# (144/366) 브리오슈 토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\브리오슈_토스트_recipe.json
#
# (145/366) 다크초코 브라우니 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\다크초코_브라우니_recipe.json
#
# (146/366) 더블 치즈 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\더블_치즈_피자_recipe.json
#
# (147/366) 스시 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\스시_recipe.json
#
# (148/366) 밀크티 소프트콘 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\밀크티_소프트콘_recipe.json
#
# (149/366) 마라탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마라탕_recipe.json
#
# (150/366) 타코야끼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타코야끼_recipe.json
#
# (151/366) 갈비찜·뼈찜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈비찜·뼈찜_recipe.json
#
# (152/366) 초코 무스 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초코_무스_케이크_recipe.json
#
# (153/366) 샌드위치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\샌드위치_recipe.json
#
# (154/366) 생크림 카스텔라 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\생크림_카스텔라_recipe.json
#
# (155/366) 달고나 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\달고나_recipe.json
#
# (156/366) 오코노미야끼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오코노미야끼_recipe.json
#
# (157/366) 곱창·막창·내장부위 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\곱창·막창·내장부위_recipe.json
#
# (158/366) 프렌치토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\프렌치토스트_recipe.json
#
# (159/366) 소바 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소바_recipe.json
#
# (160/366) 보쌈 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\보쌈_recipe.json
#
# (161/366) 찐빵 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\찐빵_recipe.json
#
# (162/366) 소고기 스튜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소고기_스튜_recipe.json
#
# (163/366) 연어 샌드위치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\연어_샌드위치_recipe.json
#
# (164/366) 바질 토마토 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_토마토_샐러드_recipe.json
#
# (165/366) 모둠 치즈 플래터 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\모둠_치즈_플래터_recipe.json
#
# (166/366) 반반치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\반반치킨_recipe.json
#
# (167/366) 돈부리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돈부리_recipe.json
#
# (168/366) 불닭 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불닭_recipe.json
#
# (169/366) 스튜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\스튜_recipe.json
#
# (170/366) 쉐이크·스무디·요거트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쉐이크·스무디·요거트_recipe.json
#
# (171/366) 버블티 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\버블티_recipe.json
#
# (172/366) 기타동물 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\기타동물_recipe.json
#
# (173/366) 크래프트 맥주 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크래프트_맥주_recipe.json
#
# (174/366) 토마토 수프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\토마토_수프_recipe.json
#
# (175/366) 번데기 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\번데기_recipe.json
#
# (176/366) 생선구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\생선구이_recipe.json
#
# (177/366) 타코 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타코_샐러드_recipe.json
#
# (178/366) 나베·전골 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\나베·전골_recipe.json
#
# (179/366) 황태 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\황태_요리_recipe.json
#
# (180/366) 햄버거 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\햄버거_recipe.json
#
# (181/366) 불고기 또띠아 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불고기_또띠아_recipe.json
#
# (182/366) 갈릭 크림치즈 베이글 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈릭_크림치즈_베이글_recipe.json
#
# (183/366) 매운탕·해물탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\매운탕·해물탕_recipe.json
#
# (184/366) 인절미 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\인절미_아이스크림_recipe.json
#
# (185/366) 타르트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타르트_recipe.json
#
# (186/366) 삼겹살 스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\삼겹살_스테이크_recipe.json
#
# (187/366) 치즈 닭갈비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치즈_닭갈비_recipe.json
#
# (188/366) 불고기 크로켓 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불고기_크로켓_recipe.json
#
# (189/366) 크림 브륄레 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크림_브륄레_recipe.json
#
# (190/366) 빙수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\빙수_recipe.json
#
# (191/366) 죽 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\죽_recipe.json
#
# (192/366) 블랙 티라미수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\블랙_티라미수_recipe.json
#
# (193/366) 불고기 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\불고기_파스타_recipe.json
#
# (194/366) 봉골레 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\봉골레_파스타_recipe.json
#
# (195/366) 찹쌀도넛 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\찹쌀도넛_recipe.json
#
# (196/366) 고로케·소시지빵·피자빵 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고로케·소시지빵·피자빵_recipe.json
#
# (197/366) 참깨 라떼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참깨_라떼_recipe.json
#
# (198/366) 바나나 크레이프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바나나_크레이프_recipe.json
#
# (199/366) 타코와사비·고노와다 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\타코와사비·고노와다_recipe.json
#
# (200/366) 치킨 파르미지아나 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치킨_파르미지아나_recipe.json
#
# (201/366) 새우 버터구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\새우_버터구이_recipe.json
#
# (202/366) 돼지갈비·주물럭·양념고기 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돼지갈비·주물럭·양념고기_recipe.json
#
# (203/366) 허니버터 감자칩 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\허니버터_감자칩_recipe.json
#
# (204/366) 바질페스토 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질페스토_피자_recipe.json
#
# (205/366) 그릭 요거트 볼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\그릭_요거트_볼_recipe.json
#
# (206/366) 스테이크 덮밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\스테이크_덮밥_recipe.json
#
# (207/366) 탄탄멘 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\탄탄멘_recipe.json
#
# (208/366) 어죽 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\어죽_recipe.json
#
# (209/366) 피자 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\피자_recipe.json
#
# (210/366) 차돌박이 숙주볶음 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\차돌박이_숙주볶음_recipe.json
#
# (211/366) 아란치니 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아란치니_recipe.json
#
# (212/366) 골뱅이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\골뱅이_recipe.json
#
# (213/366) 티라미수 마카롱 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\티라미수_마카롱_recipe.json
#
# (214/366) 오이스터 오믈렛 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오이스터_오믈렛_recipe.json
#
# (215/366) 양념치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\양념치킨_recipe.json
#
# (216/366) 갈릭버터 새우 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\갈릭버터_새우_recipe.json
#
# (217/366) 찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\찌개_recipe.json
#
# (218/366) 바질 토마토 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바질_토마토_파스타_recipe.json
#
# (219/366) 샐러드 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\샐러드_recipe.json
#
# (220/366) 라면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\라면_recipe.json
#
# (221/366) 인절미 빙수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\인절미_빙수_recipe.json
#
# (222/366) 닭똥집·모래집 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭똥집·모래집_recipe.json
#
# (223/366) 간장·마늘치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\간장·마늘치킨_recipe.json
#
# (224/366) 육회 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\육회_recipe.json
#
# (225/366) 소고기구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\소고기구이_recipe.json
#
# (226/366) 면류 레시피 검색 중...
# 레시피 검색 결과 없음: 면류
# 면류: 레시피를 찾을 수 없습니다.
#
# (227/366) 추어탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\추어탕_recipe.json
#
# (228/366) 김밥·주먹밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\김밥·주먹밥_recipe.json
#
# (229/366) 수육 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\수육_recipe.json
#
# (230/366) 물냉면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\물냉면_recipe.json
#
# (231/366) 유기농 그래놀라 볼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\유기농_그래놀라_볼_recipe.json
#
# (232/366) 회 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\회_recipe.json
#
# (233/366) 순두부찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\순두부찌개_recipe.json
#
# (234/366) 치즈 퐁듀 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치즈_퐁듀_recipe.json
#
# (235/366) 마늘빵 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마늘빵_recipe.json
#
# (236/366) 티라미수 라떼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\티라미수_라떼_recipe.json
#
# (237/366) 사케 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\사케_recipe.json
#
# (238/366) 약과·한과 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\약과·한과_recipe.json
#
# (239/366) 크루키 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크루키_recipe.json
#
# (240/366) 참치마요 주먹밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치마요_주먹밥_recipe.json
#
# (241/366) 오레오 치즈케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오레오_치즈케이크_recipe.json
#
# (242/366) 멕시칸음식 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\멕시칸음식_recipe.json
#
# (243/366) 수플레 팬케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\수플레_팬케이크_recipe.json
#
# (244/366) 홍어 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\홍어_요리_recipe.json
#
# (245/366) 돼지고기 김치찜 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돼지고기_김치찜_recipe.json
#
# (246/366) 홍시 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\홍시_아이스크림_recipe.json
#
# (247/366) 와규 스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\와규_스테이크_recipe.json
#
# (248/366) 맥주 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\맥주_recipe.json
#
# (249/366) 버섯 리조또 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\버섯_리조또_recipe.json
#
# (250/366) 쫄면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쫄면_recipe.json
#
# (251/366) 우동 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\우동_recipe.json
#
# (252/366) 육개장 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\육개장_recipe.json
#
# (253/366) 쌈밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쌈밥_recipe.json
#
# (254/366) 에스프레소·드립커피·냉침커피 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\에스프레소·드립커피·냉침커피_recipe.json
#
# (255/366) 닭강정 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭강정_recipe.json
#
# (256/366) 아보카도 김밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아보카도_김밥_recipe.json
#
# (257/366) 해산물요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\해산물요리_recipe.json
#
# (258/366) 양고기요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\양고기요리_recipe.json
#
# (259/366) 쌀국수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쌀국수_recipe.json
#
# (260/366) 초콜릿 퐁듀 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초콜릿_퐁듀_recipe.json
#
# (261/366) 꼬막 비빔밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\꼬막_비빔밥_recipe.json
#
# (262/366) 동남아음식 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\동남아음식_recipe.json
#
# (263/366) 와인 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\와인_recipe.json
#
# (264/366) 사철탕·보신탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\사철탕·보신탕_recipe.json
#
# (265/366) 제로 식품 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\제로_식품_recipe.json
#
# (266/366) 샤인머스캣 젤리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\샤인머스캣_젤리_recipe.json
#
# (267/366) 오므라이스 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오므라이스_recipe.json
#
# (268/366) 코코넛 쉬림프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\코코넛_쉬림프_recipe.json
#
# (269/366) 짬뽕·짬뽕밥·짬뽕탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\짬뽕·짬뽕밥·짬뽕탕_recipe.json
#
# (270/366) 밤티라미수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\밤티라미수_recipe.json
#
# (271/366) 오꼬노미야끼·타코야끼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오꼬노미야끼·타코야끼_recipe.json
#
# (272/366) 터키음식 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\터키음식_recipe.json
#
# (273/366) 비빔냉면 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\비빔냉면_recipe.json
#
# (274/366) 연어 덮밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\연어_덮밥_recipe.json
#
# (275/366) 전·빈대떡·부침개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\전·빈대떡·부침개_recipe.json
#
# (276/366) 랍스터 치즈구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\랍스터_치즈구이_recipe.json
#
# (277/366) 바닐라 빈 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바닐라_빈_아이스크림_recipe.json
#
# (278/366) 참치 타르타르 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\참치_타르타르_recipe.json
#
# (279/366) 흑임자 라떼 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑임자_라떼_recipe.json
#
# (280/366) 밤 몽블랑 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\밤_몽블랑_recipe.json
#
# (281/366) 티라미수 쉐이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\티라미수_쉐이크_recipe.json
#
# (282/366) 와인 페어링 디너 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\와인_페어링_디너_recipe.json
#
# (283/366) 채식·비건 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\채식·비건_요리_recipe.json
#
# (284/366) 스프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\스프_recipe.json
#
# (285/366) 그라탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\그라탕_recipe.json
#
# (286/366) 치즈 감자튀김 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치즈_감자튀김_recipe.json
#
# (287/366) 돈가스 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돈가스_recipe.json
#
# (288/366) 시나몬롤 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\시나몬롤_recipe.json
#
# (289/366) 감바스 리조또 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감바스_리조또_recipe.json
#
# (290/366) 두바이 초콜릿 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\두바이_초콜릿_recipe.json
#
# (291/366) 곤드레밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\곤드레밥_recipe.json
#
# (292/366) 해산물 크림 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\해산물_크림_파스타_recipe.json
#
# (293/366) 스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\스테이크_recipe.json
#
# (294/366) 토마토 브루스케타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\토마토_브루스케타_recipe.json
#
# (295/366) 커피 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\커피_recipe.json
#
# (296/366) 매운 라멘 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\매운_라멘_recipe.json
#
# (297/366) 흑당 크로플 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑당_크로플_recipe.json
#
# (298/366) 트러플 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_파스타_recipe.json
#
# (299/366) 족발 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\족발_recipe.json
#
# (300/366) 핫도그 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\핫도그_recipe.json
#
# (301/366) 도넛·꽈배기 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\도넛·꽈배기_recipe.json
#
# (302/366) 국밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\국밥_recipe.json
#
# (303/366) 부추전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\부추전_recipe.json
#
# (304/366) 중식요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\중식요리_recipe.json
#
# (305/366) 리소토·필라프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\리소토·필라프_recipe.json
#
# (306/366) 크로크무슈 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크로크무슈_recipe.json
#
# (307/366) 칵테일 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\칵테일_recipe.json
#
# (308/366) 치즈 등갈비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치즈_등갈비_recipe.json
#
# (309/366) 비빔밥 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\비빔밥_recipe.json
#
# (310/366) 식빵·바게트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\식빵·바게트_recipe.json
#
# (311/366) 복어요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\복어요리_recipe.json
#
# (312/366) 핫초코 브라우니 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\핫초코_브라우니_recipe.json
#
# (313/366) 블루베리 요거트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\블루베리_요거트_recipe.json
#
# (314/366) 도시락 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\도시락_recipe.json
#
# (315/366) 찜닭 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\찜닭_recipe.json
#
# (316/366) 막걸리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\막걸리_recipe.json
#
# (317/366) 까눌레 커피 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\까눌레_커피_recipe.json
#
# (318/366) 인도음식 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\인도음식_recipe.json
#
# (319/366) 홍차·녹차·밀크티 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\홍차·녹차·밀크티_recipe.json
#
# (320/366) 백숙·토종닭 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\백숙·토종닭_recipe.json
#
# (321/366) 마카롱 아이스크림 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마카롱_아이스크림_recipe.json
#
# (322/366) 단호박 스프 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\단호박_스프_recipe.json
#
# (323/366) 된장찌개·청국장 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\된장찌개·청국장_recipe.json
#
# (324/366) 과일안주 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\과일안주_recipe.json
#
# (325/366) 머핀·카스텔라 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\머핀·카스텔라_recipe.json
#
# (326/366) 고구마 스무디 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고구마_스무디_recipe.json
#
# (327/366) 성심당 베이커리 제품 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\성심당_베이커리_제품_recipe.json
#
# (328/366) 해물칼국수 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\해물칼국수_recipe.json
#
# (329/366) 낙지·오징어·쭈꾸미 요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\낙지·오징어·쭈꾸미_요리_recipe.json
#
# (330/366) 초코칩 스콘 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초코칩_스콘_recipe.json
#
# (331/366) 떡볶이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\떡볶이_recipe.json
#
# (332/366) 에그드랍 샌드위치 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\에그드랍_샌드위치_recipe.json
#
# (333/366) 국수·칼국수·수제비 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\국수·칼국수·수제비_recipe.json
#
# (334/366) 치킨가스·생선가스·규가스 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\치킨가스·생선가스·규가스_recipe.json
#
# (335/366) 부대찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\부대찌개_recipe.json
#
# (336/366) 까눌레 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\까눌레_recipe.json
#
# (337/366) 아망추 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아망추_recipe.json
#
# (338/366) 닭볶음탕 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭볶음탕_recipe.json
#
# (339/366) 홍삼 젤리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\홍삼_젤리_recipe.json
#
# (340/366) 간장·양념게장 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\간장·양념게장_recipe.json
#
# (341/366) 브루클린 핫도그 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\브루클린_핫도그_recipe.json
#
# (342/366) 생선찌개 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\생선찌개_recipe.json
#
# (343/366) 단호박 치즈 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\단호박_치즈_케이크_recipe.json
#
# (344/366) 돼지껍데기 구이 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\돼지껍데기_구이_recipe.json
#
# (345/366) 연어 스테이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\연어_스테이크_recipe.json
#
# (346/366) 순대국 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\순대국_recipe.json
#
# (347/366) 쑥 크림 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\쑥_크림_케이크_recipe.json
#
# (348/366) 만두 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\만두_recipe.json
#
# (349/366) 아구·아귀요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\아구·아귀요리_recipe.json
#
# (350/366) 떡·모찌 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\떡·모찌_recipe.json
#
# (351/366) 초코 바나나 토스트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초코_바나나_토스트_recipe.json
#
# (352/366) 요아정 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\요아정_recipe.json
#
# (353/366) 유자 샤베트 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\유자_샤베트_recipe.json
#
# (354/366) 베이크류치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\베이크류치킨_recipe.json
#
# (355/366) 한우 불고기 버거 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\한우_불고기_버거_recipe.json
#
# (356/366) 라떼류음료 레시피 검색 중...
# 요청 실패: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), 재시도 1/3
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\라떼류음료_recipe.json
#
# (357/366) 바베큐 폭립 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바베큐_폭립_recipe.json
#
# (358/366) 닭발 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭발_recipe.json
#
# (359/366) 크로플 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\크로플_recipe.json
#
# (360/366) 티라미수 팬케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\티라미수_팬케이크_recipe.json
#
# (361/366) 감자전 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\감자전_recipe.json
#
# (362/366) 트러플 오일 파스타 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_오일_파스타_recipe.json
#
# (363/366) 오믈렛 라이스 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\오믈렛_라이스_recipe.json
#
# (364/366) 프라이드치킨 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\프라이드치킨_recipe.json
#
# (365/366) 몽블랑 케이크 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\몽블랑_케이크_recipe.json
#
# (366/366) 바닷가재·게요리 레시피 검색 중...
# 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\바닷가재·게요리_recipe.json
