# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.2
# debugpy                 1.8.13
# decorator               5.2.1
# executing               2.2.0
# ipykernel               6.29.5
# ipython                 9.0.2
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# packaging               24.2
# parso                   0.8.4
# pip                     24.3.1
# platformdirs            4.3.6
# prompt_toolkit          3.0.50
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.1
# python-dateutil         2.9.0.post0
# pywin32                 309
# pyzmq                   26.2.1
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.4.2
# traitlets               5.14.3
# wcwidth                 0.2.13

# %%
# pandas, numpy 라이브러리 설치
# !pip install pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\r2com\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# requests, beautifulSoup 라이브러리 설치
# !pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, typing-extensions, soupsieve, idna, charset-normalizer, certifi, requests, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.3 certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 soupsieve-2.6 typing-extensions-4.12.2 urllib3-2.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\r2com\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import os
# Out:
# c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\menu

# %%
# 메뉴명 추출
import os
import pandas as pd
    
# 메뉴 데이터가 있는 폴더 경로 설정
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "../data/menu"))  # 상대경로 정리
menu_folder = os.path.join(data_path)

# CSV 파일 목록 가져오기
csv_files = [f for f in os.listdir(menu_folder) if f.endswith('.csv')]

# 여러 개의 CSV 파일을 하나의 DataFrame으로 합치기
menu_data_list = []
for file in csv_files:
    file_path = os.path.join(menu_folder, file)
    df = pd.read_csv(file_path, encoding='cp949') # 한글 인코딩
    df['source_file'] = file 
    menu_data_list.append(df)

# 모든 데이터를 하나의 DataFrame으로 합치기
combined_menu_data = pd.concat(menu_data_list, ignore_index=True)

# 데이터의 MENU_NM 컬람 값으로 리스트 만들기
menu_list = combined_menu_data['MENU_NM'].tolist()

# 최신 메뉴.txt 데이터 리스트에 삽입
with open(f'{data_path}/popular_menu_these_days.txt', 'r', encoding='utf-8') as f:
    temp_list = ([line.strip() for line in f.readlines()])  
    menu_list.extend(temp_list)

# 중복 제거
unique_menu_list = list(set(menu_list))

# 중복 제거한 리스트 개수 출력
print(f'중복 제거한 메뉴 개수: {len(unique_menu_list)}')

# 중복 제거한 리스트 일부 출력
unique_menu_list[:10]
# Out:
# 중복 제거한 메뉴 개수: 366
# ['라떼류음료',
#  '고르곤졸라 크림 파스타',
#  '밀푀유 나베',
#  '닭발',
#  '죽',
#  '초콜릿 퐁듀',
#  '마늘빵',
#  '고구마 스무디',
#  '흑임자 라떼',
#  '트러플 버거']

# %%
import requests, json, os, time, random
from bs4 import BeautifulSoup

# 현재 작업 디렉토리 확인 및 상대 경로 정리
BASE_DIR = os.getcwd()  # 현재 작업 디렉토리
data_path = os.path.normpath(os.path.join(BASE_DIR, "../data/recipes"))  # 상대경로 정리
os.makedirs(data_path, exist_ok=True)  # 폴더가 없으면 생성

print(f"데이터 저장 경로: {data_path}")

# 메뉴명을 입력하면 음식 정보를 출력하는 함수 (만개의 레시피 웹 스크래핑)
def food_info(name):
    recipe_list = []
    url = f"https://www.10000recipe.com/recipe/list.html?q={name}"

    # HTTP 요청 실패 시 재시도 (최대 3회)
    for attempt in range(3):
        try:
            response = requests.get(url, timeout=10)  # 타임아웃 추가
            if response.status_code == 200:
                break
            else:
                print(f"HTTP 응답 에러 ({response.status_code}), 재시도 {attempt+1}/3")
        except requests.RequestException as e:
            print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
        time.sleep(random.uniform(3, 6))  # 재시도 간격 랜덤 (3~6초)

    if response.status_code != 200:
        print(f"요청 실패: {url}")
        return None

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 번째 검색 결과에서 레시피 링크 가져오기
    food_list = soup.find_all(attrs={'class': 'common_sp_link'})
    if not food_list:
        print(f"레시피 검색 결과 없음: {name}")
        return None
    
    # 레시피는 최대 3개 저장
    for food in food_list[:3]:
        food_id = food['href'].split('/')[-1]
        new_url = f'https://www.10000recipe.com/recipe/{food_id}'

        # HTTP 요청 실패 시 재시도 (최대 3회)
        for attempt in range(3):
            try:
                new_response = requests.get(new_url, timeout=10)
                if new_response.status_code == 200:
                    break
                else:
                    print(f"레시피 페이지 요청 실패 ({new_response.status_code}), 재시도 {attempt+1}/3")
            except requests.RequestException as e:
                print(f"요청 실패: {e}, 재시도 {attempt+1}/3")
            time.sleep(random.uniform(3, 6))  # 재시도 간격 랜덤 (3~6초)

        if new_response.status_code != 200:
            print(f"레시피 페이지 요청 실패: {new_url}")
            continue

        html = new_response.text
        soup = BeautifulSoup(html, 'html.parser')

        # JSON 데이터 추출
        food_info = soup.find(attrs={'type': 'application/ld+json'})
        if food_info is None:
            print(f"JSON 데이터 없음: {new_url}")
            continue

        result = json.loads(food_info.text)

        # 'recipeIngredient'와 'recipeInstructions'가 있는지 확인
        if 'recipeIngredient' in result and 'recipeInstructions' in result:
            ingredient = ', '.join(result['recipeIngredient'])
            recipe = [step['text'] for step in result['recipeInstructions']]
            recipe = [f'{i+1}. {step}' for i, step in enumerate(recipe)]

            recipe_list.append({
                'name': name,
                'ingredients': ingredient,
                'recipe': recipe
            })

    # 3개 모두 정보가 없으면 "정보 없음" 처리
    if not recipe_list:
        recipe_list.append({
            'name': name,
            'ingredients': "정보 없음",
            'recipe': ["정보 없음"]
        })

    return recipe_list

# json 데이터를 파일로 저장하는 함수
def save_json(data, file_name):
    try:
        with open(file_name, 'w', encoding='utf-8') as file:
            json.dump(data, file, ensure_ascii=False, indent='\t')
            file.flush()  # 데이터 손실 방지
    except Exception as e:
        print(f"파일 저장 오류: {e}")

# 메뉴명 리스트로 레시피 생성 (딜레이 추가)
for i, menu in enumerate(unique_menu_list):
    print(f"\n({i+1}/{len(unique_menu_list)}) {menu} 레시피 검색 중...")

    res = food_info(menu)
    if res:
        # 파일명에서 공백 및 특수문자 처리
        safe_file_name = menu.replace(" ", "_").replace("/", "_").replace("\\", "_")
        
        # 저장 경로 조합
        file_path = os.path.join(data_path, f"{safe_file_name}_recipe.json")

        # JSON 저장
        save_json(res, file_path)
        print(f"저장 완료: {file_path}")
    else:
        print(f'{menu}: 레시피를 찾을 수 없습니다.')

    # 요청 속도를 줄이기 위해 랜덤 대기 (3~6초)
    time.sleep(random.uniform(3, 6))
# Out:
# 데이터 저장 경로: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes
#
# 🔎 (1/366) 라떼류음료 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\라떼류음료_recipe.json
#
# 🔎 (2/366) 고르곤졸라 크림 파스타 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고르곤졸라_크림_파스타_recipe.json
#
# 🔎 (3/366) 밀푀유 나베 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\밀푀유_나베_recipe.json
#
# 🔎 (4/366) 닭발 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\닭발_recipe.json
#
# 🔎 (5/366) 죽 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\죽_recipe.json
#
# 🔎 (6/366) 초콜릿 퐁듀 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\초콜릿_퐁듀_recipe.json
#
# 🔎 (7/366) 마늘빵 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\마늘빵_recipe.json
#
# 🔎 (8/366) 고구마 스무디 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\고구마_스무디_recipe.json
#
# 🔎 (9/366) 흑임자 라떼 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\흑임자_라떼_recipe.json
#
# 🔎 (10/366) 트러플 버거 레시피 검색 중...
# ✅ 저장 완료: c:\Users\r2com\Documents\GitHub\BeBaek\ChefBot\data\recipes\트러플_버거_recipe.json

# %%
# menu 디렉토리로 다시 이동
os.chdir('..')
os.chdir('./menu')
